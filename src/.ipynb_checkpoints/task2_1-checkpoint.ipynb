# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from collections import Counter
from sklearn.preprocessing import MinMaxScaler
# @github https://github.com/LKI/chinese-calendar
from chinese_calendar import is_workday
plt.rcParams['axes.unicode_minus'] = False
# plt.rcParams['font.sans-serif'] = ['STHeiti']
plt.rcParams['font.sans-serif'] = ['Simhei']

# %%
def time_map(time_str):  
    if time_str is None:  
        return ''  
    hour = int(time_str.split(':')[0])  
    if hour < 11:  
        return 'Breakfast'  
    elif hour < 17:  
        return 'Lunch'  
    else:  
        return 'Dinner'

# %%
def isWork(date: list):
    """判断是否工作"""
    return is_workday(datetime.date(date[0], date[1], date[2]))

# %%
data2=pd.read_csv('data/task1_2_1.csv',encoding='gbk')

# %%
# 得到map映射的用餐类型
have_meal = data2.copy()
have_meal['Meal'] = have_meal['Time'].apply(time_map)
have_meal = have_meal[have_meal.Meal != '']
display(have_meal)
# Out:
#         Index  CardNo Sex   Major  AccessCardNo       Date  Money  FundMoney  \
# 0           1  180001   男  18国际金融      19762330  2019/4/21    7.0        0.0
# 1           1  180001   男  18国际金融      19762330  2019/4/22    3.5        0.0
# 2           1  180001   男  18国际金融      19762330  2019/4/10   11.0        0.0
# 3           1  180001   男  18国际金融      19762330  2019/4/15    7.0        0.0
# 4           1  180001   男  18国际金融      19762330  2019/4/15    2.5        0.0
# ...       ...     ...  ..     ...           ...        ...    ...        ...
# 241074   4339  184339   女  18工业工程      11513762  2019/4/18    2.5        0.0
# 241075   4339  184339   女  18工业工程      11513762  2019/4/15    4.1        0.0
# 241076   4339  184339   女  18工业工程      11513762  2019/4/15    0.6        0.0
# 241077   4339  184339   女  18工业工程      11513762  2019/4/15    6.0        0.0
# 241078   4339  184339   女  18工业工程      11513762  2019/4/12    0.5        0.0
#
#         Surplus  CardCount Type  TermNo  OperNo  Dept   Time       Meal
# 0          28.4      206.0   消费    41.0   249.0  第四食堂  18:30     Dinner
# 1          24.9      207.0   消费    19.0   236.0  第一食堂  09:40  Breakfast
# 2           2.7      189.0   消费    82.0    18.0  第四食堂  16:42      Lunch
# 3          43.2      192.0   消费    62.0     2.0  第四食堂  11:43      Lunch
# 4          50.2      191.0   消费     2.0   236.0  第一食堂  07:50  Breakfast
# ...         ...        ...  ...     ...     ...   ...    ...        ...
# 241074     78.8      551.0   消费   118.0   204.0  第五食堂  18:13     Dinner
# 241075     46.5      526.0   消费   114.0     8.0  第五食堂  07:26  Breakfast
# 241076     45.9      527.0   消费   127.0   204.0  第五食堂  07:27  Breakfast
# 241077     39.9      528.0   消费   132.0   204.0  第五食堂  13:14      Lunch
# 241078     58.3      521.0   消费   141.0   204.0  第五食堂  15:05      Lunch
#
# [241079 rows x 16 columns]

# %%
# 绘制饼图为每一餐使用地点
meals = have_meal['Meal'].unique()  
meals
# Out:
# array(['Dinner', 'Breakfast', 'Lunch'], dtype=object)

# %%
# 为每一餐分别绘制饼状图  
for meal in meals:  
    # 筛选出当前餐的地点数据  
    meal_data = have_meal[have_meal['Meal'] == meal]  
    
    # 统计每个地点的数量  
    location_counts = meal_data['Dept'].value_counts()  
    top_counts = location_counts.nlargest(7)  # 获取前7个地点  

    # 绘制饼状图  
    plt.figure(figsize=(6, 6))  
    
    # 设置颜色  
    colors = plt.cm.Paired(range(len(top_counts)))  # 使用Paired颜色映射  
    
    # 突出显示食用最多的地点  
    explode = [0.1 if count == top_counts.max() else 0 for count in top_counts]  

    plt.pie(top_counts, labels=top_counts.index, autopct='%1.1f%%', startangle=140, explode=explode, colors=colors)  
    
    plt.title(f'{meal} 食用地点分布')  
    plt.axis('equal')  # 保证饼图为圆形  
    plt.show()
